# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/balanced-dataset/new_data/valid/labels/9363.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/11_jpeg.rf.3221545e6a4ac2498f19a54651d41874.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/1773.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/1812.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/5993.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/8798.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/3926.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/1880.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/557.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/2842.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/5020.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/10621.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/8563.txt
# /kaggle/input/balanced-dataset/new_data/valid/labels/photo_80_2024-02-22_07-38-32_jpg.rf.5501fa85b9c9d6a3abcfc34bfd39555a.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 566.4 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.6/749.6 kB 4.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install Ipython

# %%
import os
from IPython import display
display.clear_output()
from IPython.display import display, Image
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5519.7/8062.4 GB disk)

# %%
model = YOLO("yolov9m.pt")
train = model.train(data='/kaggle/input/yaml-file-for-balanced-dataset/data.yaml' , epochs=80 ,imgsz = 640 , batch=30)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/kaggle/working/runs/detect/train/results.png',width=640)

# %%
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")
train = model.train(data='/kaggle/input/yaml-file-for-balanced-dataset/data.yaml' , epochs=10 ,imgsz = 640 , batch=30)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...
